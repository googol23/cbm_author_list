# %%
import json
import pandas as pd

author_df = pd.read_csv("persons.csv")[["givenname", "familyname", "initials", "email", "prim_affil"]]
author_df["fullname"] = author_df["givenname"] + " " + author_df["familyname"]
author_df["prim_affil"] = author_df["prim_affil"].apply(lambda x: x[1:-1])
author_df.sort_values("familyname", inplace=True)
author_df = author_df.set_index("fullname")

institution_df = pd.read_csv("institutions.csv")[["mnemonic", "city", "country", "name", "representative"]].set_index("mnemonic")

for index, row in author_df.iterrows():
    # Check if the initials are missing and generate them from the given name
    if pd.isnull(row['initials']):
        given_name = row['givenname'].strip().split()
        author_df.loc[index, 'initials'] = "".join([name[0].upper() + "." for name in given_name])
    else:
        author_df.loc[index, 'initials'] = row['initials'].strip()

    # Check if the email is missing and assign it based on the representative's email
    if pd.isnull(row['email']):
        representative = institution_df.loc[row["prim_affil"], "representative"]
        author_df.loc[index, 'email'] = author_df.loc[representative, "email"] if not pd.isnull(representative) else "noemail"
    else:
        author_df.loc[index, 'email'] = row['email'].strip()

# %%
"""
    % Example output format for authors and affiliations in LaTeX

    \author[1]{1.~Author}[type=collab]
    \ead{author1@gsi.de}
    \credit{did nothing}
    \affiliation[1]{
        organization={Affiliation 1},
        city={Affiliation 1 City},
        country={Affiliation 1 Country},
    }
"""
registered_affiliations = []
affiliation_tex = ""
auhtor_tex = ""
aff_idx = 0
for index, row in author_df.iterrows():
    author = row['initials'] + ",~" + "~".join(row['familyname'].split())

    #### Exlucde authors by rules ###
    author_aff = institution_df.loc[row["prim_affil"]]
    if author_aff.country.lower() == "russia":
        continue

    #################################
    if row["prim_affil"] not in registered_affiliations:
        registered_affiliations.append(row["prim_affil"] )

    aff_idx = registered_affiliations.index(row["prim_affil"])
    auhtor_tex += "\\author[" + str(aff_idx+1) + "]{" + author + "}[type=collab]\n" + \
        "\\ead{" + row['email'] + "}\n\n"


for aff_idx, aff in enumerate(registered_affiliations):
    row = institution_df.loc[aff]
    affiliation_tex += \
        "\\affiliation[" + str(aff_idx+1) + "]{\n" + \
        "\torganization={" + row['name'].strip() + "},\n" + \
        "\tcity={" + row['city'].strip() + "},\n" + \
        "\tcountry={" + row['country'].strip() + "}\n" + \
        "}\n"

with open("authors_affiliations.tex", "w", encoding="utf-8") as o_file:
    o_file.write(auhtor_tex)
    o_file.write(affiliation_tex)

# %% [markdown]
# ##### Using the author list from Walter's file

# %%
def levenshtein_distance(s1, s2):
    s1 = s1.lower()
    s2 = s2.lower()
    if len(s1) < len(s2):
        return levenshtein_distance(s2, s1)

    if len(s2) == 0:
        return len(s1)

    previous_row = list(range(len(s2) + 1))
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions  = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]

def find_best_match_index(query, df, max_distance=2):
    query = query.lower()
    best_index = -1
    best_score = float('inf')

    print("looking a match for:", query)
    for index, row in df.iterrows():
        dist = levenshtein_distance(query, index.lower())
        if dist < best_score and dist <= max_distance:
            best_score = dist
            best_index = index
    return best_index

# %%
# Load author list from Walter's file
authors_to_include = []
with open("sts_cbmcdb.tex", "r") as f:
    lines = f.readlines()
    for line in lines:
        if line.startswith("\\author"):
            # Take out comments in the line
            line = line.split("%%")
            name = line[1].split(" (")[0].strip()

            lastname = line[0].strip()
            open_brace_index = lastname.find("{") + 1
            close_brace_index = lastname.rfind("}")
            lastname = lastname[open_brace_index:close_brace_index].strip()
            if '.~' in lastname:
                lastname = lastname.split('.~')[1].strip()

            # Clean up LaTeX characters
            name = name.translate(str.maketrans('', '', '\{\}\\"^\'~'))
            lastname = lastname.translate(str.maketrans('', '', '\{\}\\"^\'~'))

            if len(name):
                authors_to_include.append(name+" "+lastname)
            else:
                authors_to_include.append(lastname)

print(authors_to_include)
# Out:
# ['Apar Agarwal', 'Kshitij Agarwal', 'Zubayer Ahammed', 'Nazeer Ahmad', 'Luca Jonas Ahrens', 'Mohammad Al-Turany', 'Noor Alam', 'Julio Andary', 'Anton Andronic', 'Harald Appelshauser', 'Benedict Arnoldi-Meadows', 'Beatriz Artur', 'Mohd. Danish Azmi', 'Marcel Bajdel', 'Matthias Balzer', 'Arup Bandyopadhyay', 'Vlad Andrei Basceanu', 'Jurgen Becker', 'Marten Becker', 'Artemiy Belousov', 'Alexandru Bercuci', 'Roland Berendes', 'Denis Bertini', 'Olga Bertini', 'Martin Beyer', 'Oleg Bezshyyko', 'Partha Pratim Bhaduri', 'Anju Bhasin', 'Shabir Ahmad Bhat', 'Towseef Ahmad Bhat', 'Waseem Ahmad Bhat', 'Buddhadeb Bhattacharjee', 'Abhijit Bhattacharyya', 'Nilay Kumar Bhowmik', 'Saikat Biswas', 'Thomas Blank', 'Nora Bluhme', 'Christoph Blume', 'Gianluca Boccarella', 'Daniel Bonaventura', 'Janusz Brzychczyk', 'Marius Calin', 'Michele Caselle', 'Amlan Chakrabarti', 'Petr Chaloupka', 'Souvik Chattopadhyay', 'Subhasis Chattopadhyay', 'Hamda Cherif', 'Serhii Chernyshenko', 'Eoin Clerkin', 'Lady Maryann Collazo Sanchez', 'Mate Csanad', 'Patrick Dahm', 'Aizat Daribayeva', 'Hasan Darwish', 'Rudrapriya Das', 'Supriya Das', 'Jan de Cuveland', 'Diana-Andreea Dearua', 'Harald Deppe', 'Ingo Deppner', 'Abhishek Anil Deshmukh', 'Michael Deveaux', 'Jonathan Diehl', 'Vasyl Dobishuk', 'Anand Kumar Dubey', 'Andrea Dubla', 'Michael Durr', 'Radim Dvovrak', 'Ilya Elizarov', 'David Emschermann', 'Jurgen Eschke', 'Luisa Johanna Faber', 'Cornelius Feier-Riesen', 'Sheng-Qin Feng', 'Felix Fidorra', 'Peter Fischer', 'Holger Flemming', 'Jorg Fortsch', 'Panagiota Foka', 'Ulrich Frankenfeld', 'Volker Friese', 'Ingo Frohlich', 'Jochen Fruhauf', 'Tetyana Galatyuk', 'Gautam Gangopadhyay', 'Piotr Gasik', 'Chandrasekhar Ghosh', 'Sanjay K. Ghosh', 'Damian Gil', 'Susanne Glassel', 'Frank Goldenbaum', 'Larisa Golinka-Bezshyyko', 'Somen Gope', 'Sergey Gorbunov', 'Nico Greve', 'Dieter Grzonka', 'Anik Gupta', 'David Gutierrez Menendez', 'Benedikt Gutsche', 'Dong Han', 'Junyi Han', 'Norbert Heine', 'Norbert Herrmann', 'Helena Hesounova', 'Johann M. Heuser', 'Claudia Hohne', 'Felix Hoffmann', 'Ondvrej Hofman', 'Romain Holzmann', 'Yige Huang', 'Dirk Hutter', 'Khaled Ismail', 'Thomas Janson', 'Yixuan Jin', 'Alexandru Jipa', 'Igor Kadenko', 'Philipp Kahler', 'Karl-Heinz Kampert', 'Ralf Michael Kapell', 'Radoslaw Karabowicz', 'Varchaswi K.S. Kashyap', 'Krzysztof Kasinski', 'Vadym Kedych', 'Oliver Keller', 'Irakli Keshelashvili', 'M. Mohsin Khan', 'Sukyung Kim', 'Mladen Kivs', 'Ivan Kisel', 'Rafal Kleczek', 'Christian Klein-Bosing', 'Ralf Kliemt', 'Karsten Koch', 'Piotr Koczon', 'Martin Kohn', 'Jan Kollarczyk', 'Oleksii Kovalchuk', 'Michal Koziel', 'Grigory Kozlov', 'Dmytro Kresan', 'Wilhelm Kruger', 'Michal Kruszewski', 'Oleksandr Kshyvanskyi', 'Bogumil Kubiak', 'Andrej Kugler', 'Ajay Kumar', 'Ajit Kumar', 'Lokesh Kumar', 'Volodymyr Kyva', 'Robin Lakos', 'Rafal Lalik', 'Pawel Lasko', 'Evgeny Lavrik', 'Ionel Lazanu', 'Jorg Lehnert', 'Yue Hang Leung', 'Shuang Li', 'Wen Li', 'Yuanjing Li', 'Volker Lindenstruth', 'Frederic Julian Linz', 'Feng Liu', 'Sven Lochner', 'Pierre-Alain Loizeau', 'Manuel Lorenz', 'Oleksii Lubynets', 'Xiaofeng Luo', 'Anton Lymanets', 'Sanjay Mahajan', 'Zbigniew Majka', 'Biswajit Mallick', 'Subir Mandal', 'Yaxian Mao', 'Osnan Maragoto Rodriguez', 'Ana Maria Marin Garcia', 'Jochen Markert', 'Franz Alexej Matejcek', 'Tomasz Matulewicz', 'Johan Messchendorp', 'Shaifali Mehta', 'Adrian Meyer-Ahrens', 'Jan Michel', 'M. Farooq Mir', 'Dariusz Miskowiec', 'Akhil Mithran', 'Bedangadas Mohanty', 'Ievgeniia Momot', 'Denise Moreira de Godoy Willems', 'Walter F.J. Muller', 'Christian Muntz', 'Philipp Munkes', 'Marvin Nabroth', 'Ekata Nandy', 'Satya Ranjan Nayak', 'Frank Nerling', 'Simon Neuhaus', 'Frederike Nickels', 'Dachi Okropiridze', 'Antonin Opichal', 'Piotr Otfinowski', 'Liang-ming Pan', 'Iaroslav Panasenko', 'Christian Pauly', 'Jesus Pena Rodriguez', 'Omer Penek', 'Sven Peter', 'Vojtvech Petravcek', 'Mariana Petrics', 'Mihai Petrovici', 'Dennis Pfeifer', 'Krzysztof Piasecki', ...

# %%
"""
    % Example output format for authors and affiliations in LaTeX

    \author[1]{1.~Author}[type=collab]
    \ead{author1@gsi.de}
    \credit{did nothing}
    \affiliation[1]{
        organization={Affiliation 1},
        city={Affiliation 1 City},
        country={Affiliation 1 Country},
    }
"""
author_matches = 0
missing_authors = []
registered_affiliations = []
affiliation_tex = ""
auhtor_tex = ""
aff_idx = 0

for author in authors_to_include:
    match_index = find_best_match_index(author, author_df, 5)
    if match_index == -1:
        missing_authors.append(author)
        continue

    author_matches += 1

    row = author_df.loc[match_index]
    author = row['initials'] + ",~" + "~".join(row['familyname'].split())
    author_aff = institution_df.loc[row["prim_affil"]]

    print(f"{author} matched with {match_index} -> {author}")

    # .tex building rules for authors
    if row["prim_affil"] not in registered_affiliations:
        registered_affiliations.append(row["prim_affil"] )

    aff_idx = registered_affiliations.index(row["prim_affil"])

    auhtor_tex += "\\author[" + str(aff_idx+1) + "]{" + author + "}[type=collab]\n" + \
        "\\ead{" + row['email'] + "}\n\n"


for aff_idx, aff in enumerate(registered_affiliations):
    row = institution_df.loc[aff]
    affiliation_tex += \
        "\\affiliation[" + str(aff_idx+1) + "]{\n" + \
        "\torganization={" + row['name'].strip() + "},\n" + \
        "\tcity={" + row['city'].strip() + "},\n" + \
        "\tcountry={" + row['country'].strip() + "}\n" + \
        "}\n"

with open("authors_affiliations.tex", "w", encoding="utf-8") as o_file:
    o_file.write(auhtor_tex)
    o_file.write(affiliation_tex)

print(author_matches, len(authors_to_include))
print(missing_authors)
# Out:
# looking a match for: apar agarwal
# A.,~Agarwal matched with Apar Agarwal -> A.,~Agarwal
# looking a match for: kshitij agarwal
# K.,~Agarwal matched with Kshitij Agarwal -> K.,~Agarwal
# looking a match for: zubayer ahammed
# Z.,~Ahammed matched with Zubayer Ahammed -> Z.,~Ahammed
# looking a match for: nazeer ahmad
# N.,~Ahmad matched with Nazeer Ahmad -> N.,~Ahmad
# looking a match for: luca jonas ahrens
# L.J.,~Ahrens matched with Luca Jonas Ahrens -> L.J.,~Ahrens
# looking a match for: mohammad al-turany
# M.,~Al-Turany matched with Mohammad Al-Turany -> M.,~Al-Turany
# looking a match for: noor alam
# N.,~Alam matched with Noor Alam -> N.,~Alam
# looking a match for: julio andary
# J.,~Andary matched with Julio Andary -> J.,~Andary
# looking a match for: anton andronic
# A.,~Andronic matched with Anton Andronic -> A.,~Andronic
# looking a match for: harald appelshauser
# H.,~Appelshäuser matched with Harald Appelshäuser -> H.,~Appelshäuser
# looking a match for: benedict arnoldi-meadows
# B.,~Arnoldi-Meadows matched with Benedict Arnoldi-Meadows -> B.,~Arnoldi-Meadows
# looking a match for: beatriz artur
# B.,~Artur matched with Beatriz Artur -> B.,~Artur
# looking a match for: mohd. danish azmi
# M.D.,~Azmi matched with Mohd. Danish Azmi -> M.D.,~Azmi
# looking a match for: marcel bajdel
# M.,~Bajdel matched with Marcel Bajdel -> M.,~Bajdel
# looking a match for: matthias balzer
# M.,~Balzer matched with Matthias Balzer -> M.,~Balzer
# looking a match for: arup bandyopadhyay
# A.,~Bandyopadhyay matched with Arup Bandyopadhyay -> A.,~Bandyopadhyay
# looking a match for: vlad andrei basceanu
# V.A.,~Bâsceanu matched with Vlad Andrei Bâsceanu -> V.A.,~Bâsceanu
# looking a match for: jurgen becker
# J.,~Becker matched with Jürgen Becker -> J.,~Becker
# looking a match for: marten becker
# M.,~Becker matched with Marten Becker -> M.,~Becker
# looking a match for: artemiy belousov
# A.,~Belousov matched with Artemiy Belousov -> A.,~Belousov
# looking a match for: alexandru bercuci
# A.,~Bercuci matched with Alexandru Bercuci -> A.,~Bercuci
# looking a match for: roland berendes
# R.,~Berendes matched with Roland Berendes -> R.,~Berendes
# looking a match for: denis bertini
# D.,~Bertini matched with Denis Bertini -> D.,~Bertini
# looking a match for: olga bertini
# O.,~Bertini matched with Olga Bertini -> O.,~Bertini
# looking a match for: martin beyer
# M.,~Beyer matched with Martin Beyer -> M.,~Beyer
# looking a match for: oleg bezshyyko
# O.,~Bezshyyko matched with Oleg Bezshyyko -> O.,~Bezshyyko
# looking a match for: partha pratim bhaduri
# P.P.,~Bhaduri matched with Partha Pratim Bhaduri -> P.P.,~Bhaduri
# looking a match for: anju bhasin
# A.,~Bhasin matched with Anju Bhasin -> A.,~Bhasin
# looking a match for: shabir ahmad bhat
# S.A.,~Bhat matched with Shabir Ahmad Bhat -> S.A.,~Bhat
# looking a match for: towseef ahmad bhat
# T.A.,~Bhat matched with Towseef Ahmad Bhat -> T.A.,~Bhat
# looking a match for: waseem ahmad bhat
# W.A.,~Bhat matched with Waseem Ahmad Bhat -> W.A.,~Bhat
# looking a match for: buddhadeb bhattacharjee
# B.,~Bhattacharjee matched with Buddhadeb Bhattacharjee -> B.,~Bhattacharjee
# looking a match for: abhijit bhattacharyya
# A.,~Bhattacharyya matched with Abhijit Bhattacharyya -> A.,~Bhattacharyya
# looking a match for: nilay kumar bhowmik
# N.K.,~Bhowmik matched with Nilay Kumar Bhowmik -> N.K.,~Bhowmik
# looking a match for: saikat biswas
# S.,~Biswas matched with Saikat Biswas -> S.,~Biswas
# looking a match for: thomas blank
# T.,~Blank matched with Thomas Blank -> T.,~Blank
# looking a match for: nora bluhme
# N.,~Bluhme matched with Nora Bluhme -> N.,~Bluhme
# looking a match for: christoph blume
# C.,~Blume matched with Christoph Blume -> C.,~Blume
# looking a match for: gianluca boccarella
# G.,~Boccarella matched with Gianluca Boccarella -> G.,~Boccarella
# looking a match for: daniel bonaventura
# D.,~Bonaventura matched with Daniel Bonaventura -> D.,~Bonaventura
# looking a match for: janusz brzychczyk
# J.,~Brzychczyk matched with Janusz Brzychczyk -> J.,~Brzychczyk
# looking a match for: marius calin
# M.,~Cãlin matched with Marius Cãlin -> M.,~Cãlin
# looking a match for: michele caselle
# M.,~Caselle matched with Michele Caselle -> M.,~Caselle
# looking a match for: amlan chakrabarti
# A.,~Chakrabarti matched with Amlan Chakrabarti -> A.,~Chakrabarti
# looking a match for: petr chaloupka
# P.,~Chaloupka matched with Petr Chaloupka -> P.,~Chaloupka
# looking a match for: souvik chattopadhyay
# S.,~Chattopadhyay matched with Souvik Chattopadhyay -> S.,~Chattopadhyay
# looking a match for: subhasis chattopadhyay
# S.,~Chattopadhyay matched with Subhasis Chattopadhyay -> S.,~Chattopadhyay
# looking a match for: hamda cherif
# H.,~Cherif matched with Hamda Cherif -> H.,~Cherif
# looking a match for: serhii chernyshenko
# S.,~Chernyshenko matched with Serhii Chernyshenko -> S.,~Chernyshenko
# looking a match for: eoin clerkin
# E.,~Clerkin matched with Eoin Clerkin -> E.,~Clerkin
# looking a match for: lady maryann collazo sanchez
# L.M.,~Collazo~Sánchez matched with Lady Maryann Collazo Sánchez -> L.M.,~Collazo~Sánchez
# looking a match for: mate csanad
# M.,~Csanád matched with Máté Csanád -> M.,~Csanád
# looking a match for: patrick dahm
# P.,~Dahm matched with Patrick Dahm -> P.,~Dahm
# looking a match for: aizat daribayeva
# A.,~Daribayeva matched with Aizat Daribayeva -> A.,~Daribayeva
# looking a match for: hasan darwish
# H.,~Darwish matched with Hasan Darwish -> H.,~Darwish
# looking a match for: rudrapriya das
# R.,~Das matched with Rudrapriya Das -> R.,~Das
# looking a match for: supriya das
# S.,~Das matched with Supriya Das -> S.,~Das
# looking a match for: jan de cuveland
# J.,~de~Cuveland matched with Jan de Cuveland -> J.,~de~Cuveland
# looking a match for: diana-andreea dearua
# D.-A.,~Deară matched with Diana-Andreea Deară -> D.-A.,~Deară
# looking a match for: harald deppe
# H.,~Deppe matched with Harald Deppe -> H.,~Deppe
# looking a match for: ingo deppner
# I.,~Deppner matched with Ingo Deppner -> I.,~Deppner
# looking a match for: abhishek anil deshmukh
# A.A.,~Deshmukh matched with Abhishek Anil Deshmukh -> A.A.,~Deshmukh
# looking a match for: michael deveaux
# M.,~Deveaux matched with Michael Deveaux -> M.,~Deveaux
# looking a match for: jonathan diehl
# J.,~Diehl matched with Jonathan Diehl -> J.,~Diehl
# looking a match for: vasyl dobishuk
# V.,~Dobishuk matched with Vasyl Dobishuk -> V.,~Dobishuk
# looking a match for: anand kumar dubey
# A.K.,~Dubey matched with Anand Kumar Dubey -> A.K.,~Dubey
# looking a match for: andrea dubla
# A.,~Dubla matched with Andrea Dubla -> A.,~Dubla
# looking a match for: michael durr
# M.,~Dürr matched with Michael Dürr -> M.,~Dürr
# looking a match for: radim dvovrak
# R.,~Dvořák matched with Radim Dvořák -> R.,~Dvořák
# looking a match for: ilya elizarov
# I.,~Elizarov matched with Ilya Elizarov -> I.,~Elizarov
# looking a match for: david emschermann
# D.,~Emschermann matched with David Emschermann -> D.,~Emschermann
# looking a match for: jurgen eschke
# J.,~Eschke matched with Jürgen Eschke -> J.,~Eschke
# looking a match for: luisa johanna faber
# L.J.,~Faber matched with Luisa Johanna Faber -> L.J.,~Faber
# looking a match for: cornelius feier-riesen
# C.,~Feier-Riesen matched with Cornelius Feier-Riesen -> C.,~Feier-Riesen
# looking a match for: sheng-qin feng
# S.,~Feng matched with Sheng-Qin Feng -> S.,~Feng
# looking a match for: felix fidorra
# F.,~Fidorra matched with Felix Fidorra -> F.,~Fidorra
# looking a match for: peter fischer
# P.,~Fischer matched with Peter Fischer -> P.,~Fischer
# looking a match for: holger flemming
# H.,~Flemming matched with Holger Flemming -> H.,~Flemming
# looking a match for: jorg fortsch
# J.,~Förtsch matched with Jörg Förtsch -> J.,~Förtsch
# looking a match for: panagiota foka
# P.,~Foka matched with Panagiota Foka -> P.,~Foka
# looking a match for: ulrich frankenfeld
# U.,~Frankenfeld matched with Ulrich Frankenfeld -> U.,~Frankenfeld
# looking a match for: volker friese
# V.,~Friese matched with Volker Friese -> V.,~Friese
# looking a match for: ingo frohlich
# I.,~Fröhlich matched with Ingo Fröhlich -> I.,~Fröhlich
# looking a match for: jochen fruhauf
# J.,~Frühauf matched with Jochen Frühauf -> J.,~Frühauf
# looking a match for: tetyana galatyuk
# T.,~Galatyuk matched with Tetyana Galatyuk -> T.,~Galatyuk
# looking a match for: gautam gangopadhyay
# G.,~Gangopadhyay matched with Gautam Gangopadhyay -> G.,~Gangopadhyay
# looking a match for: piotr gasik
# P.,~Gasik matched with Piotr Gasik -> P.,~Gasik
# looking a match for: chandrasekhar ghosh
# C.,~Ghosh matched with Chandrasekhar Ghosh -> C.,~Ghosh
# looking a match for: sanjay k. ghosh
# S.K.,~Ghosh matched with Sanjay K. Ghosh -> S.K.,~Ghosh
# looking a match for: damian gil
# D.,~Gil matched with Damian Gil -> D.,~Gil
# looking a match for: susanne glassel
# S.,~Gläßel matched with Susanne Gläßel -> S.,~Gläßel
# looking a match for: frank goldenbaum
# F.,~Goldenbaum matched with Frank Goldenbaum -> F.,~Goldenbaum
# looking a match for: larisa golinka-bezshyyko
# L.,~Golinka-Bezshyyko matched with Larisa Golinka-Bezshyyko -> L.,~Golinka-Bezshyyko
# looking a match for: somen gope
# S.,~Gope matched with Somen Gope -> S.,~Gope
# looking a match for: sergey gorbunov
# S.,~Gorbunov matched with Sergey Gorbunov -> S.,~Gorbunov
# looking a match for: nico greve
# N.,~Greve matched with Nico Greve -> N.,~Greve
# looking a match for: dieter grzonka
# D.,~Grzonka matched with Dieter Grzonka -> D.,~Grzonka
# looking a match for: anik gupta
# A.,~Gupta matched with Anik Gupta -> A.,~Gupta
# looking a match for: david gutierrez menendez
# D.,~Gutiérrez~Menéndez matched with David Gutiérrez Menéndez -> D.,~Gutiérrez~Menéndez
# looking a match for: benedikt gutsche
# B.,~Gutsche matched with Benedikt Gutsche -> B.,~Gutsche
# looking a match for: dong han
# D.,~Han matched with Dong Han -> D.,~Han
# looking a match for: junyi han
# J.,~Han matched with Junyi Han -> J.,~Han
# looking a match for: norbert heine
# N.,~Heine matched with Norbert Heine -> N.,~Heine
# looking a match for: norbert herrmann
# N.,~Herrmann matched with Norbert Herrmann -> N.,~Herrmann
# looking a match for: helena hesounova
# H.,~Hesounová matched with Helena Hesounová -> H.,~Hesounová
# looking a match for: johann m. heuser
# J.M.,~Heuser matched with Johann M. Heuser -> J.M.,~Heuser
# looking a match for: claudia hohne
# C.,~Höhne matched with Claudia Höhne -> C.,~Höhne
# looking a match for: felix hoffmann
# F.,~Hoffmann matched with Felix Hoffmann -> F.,~Hoffmann
# looking a match for: ondvrej hofman
# O.,~Hofman matched with Ondřej Hofman -> O.,~Hofman
# looking a match for: romain holzmann
# R.,~Holzmann matched with Romain Holzmann -> R.,~Holzmann
# looking a match for: yige huang
# Y.,~Huang matched with Yige Huang -> Y.,~Huang
# looking a match for: dirk hutter
# D.,~Hutter matched with Dirk Hutter -> D.,~Hutter
# looking a match for: khaled ismail
# K.,~Ismail matched with Khaled Ismail -> K.,~Ismail
# looking a match for: thomas janson
# T.,~Janson matched with Thomas Janson -> T.,~Janson
# looking a match for: yixuan jin
# Y.,~Jin matched with Yixuan Jin -> Y.,~Jin
# looking a match for: alexandru jipa
# A.,~Jipa matched with Alexandru Jipa -> A.,~Jipa
# looking a match for: igor kadenko
# I.,~Kadenko matched with Igor Kadenko -> I.,~Kadenko
# looking a match for: philipp kahler
# P.,~Kähler matched with Philipp Kähler -> P.,~Kähler
# looking a match for: karl-heinz kampert
# K.-H.,~Kampert matched with Karl-Heinz Kampert -> K.-H.,~Kampert
# looking a match for: ralf michael kapell
# R.M.,~Kapell matched with Ralf Michael Kapell -> R.M.,~Kapell
# looking a match for: radoslaw karabowicz
# R.,~Karabowicz matched with Radoslaw Karabowicz -> R.,~Karabowicz
# looking a match for: varchaswi k.s. kashyap
# V.K.S.,~Kashyap matched with Varchaswi K.S. Kashyap -> V.K.S.,~Kashyap
# looking a match for: krzysztof kasinski
# K.,~Kasiński matched with Krzysztof Kasiński -> K.,~Kasiński
# looking a match for: vadym kedych
# V.,~Kedych matched with Vadym Kedych -> V.,~Kedych
# looking a match for: oliver keller
# O.,~Keller matched with Oliver Keller -> O.,~Keller
# looking a match for: irakli keshelashvili
# I.,~Keshelashvili matched with Irakli Keshelashvili -> I.,~Keshelashvili
# looking a match for: m. mohsin khan
# M.M.,~Khan matched with M. Mohsin Khan -> M.M.,~Khan
# looking a match for: sukyung kim
# S.,~Kim matched with Sukyung Kim -> S.,~Kim
# looking a match for: mladen kivs
# M.,~Kiš matched with Mladen Kiš -> M.,~Kiš
# looking a match for: ivan kisel
# I.,~Kisel matched with Ivan Kisel -> I.,~Kisel
# looking a match for: rafal kleczek
# R.,~Kłeczek matched with Rafał Kłeczek -> R.,~Kłeczek
# looking a match for: christian klein-bosing
# Ch.,~Klein-Bösing matched with Christian Klein-Bösing -> Ch.,~Klein-Bösing
# looking a match for: ralf kliemt
# R.,~Kliemt matched with Ralf Kliemt -> R.,~Kliemt
# looking a match for: karsten koch
# K.,~Koch matched with Karsten Koch -> K.,~Koch
# looking a match for: piotr koczon
# P.,~Koczoń matched with Piotr Koczoń -> P.,~Koczoń
# looking a match for: martin kohn
# M.,~Kohn matched with Martin Kohn -> M.,~Kohn
# looking a match for: jan kollarczyk
# J.,~Kollarczyk matched with Jan Kollarczyk -> J.,~Kollarczyk
# looking a match for: oleksii kovalchuk
# O.,~Kovalchuk matched with Oleksii Kovalchuk -> O.,~Kovalchuk
# looking a match for: michal koziel
# M.,~Koziel matched with Michał Koziel -> M.,~Koziel
# looking a match for: grigory kozlov
# G.,~Kozlov matched with Grigory Kozlov -> G.,~Kozlov
# looking a match for: dmytro kresan
# D.,~Kresan matched with Dmytro Kresan -> D.,~Kresan
# looking a match for: wilhelm kruger
# W.,~Krüger matched with Wilhelm Krüger -> W.,~Krüger
# looking a match for: michal kruszewski
# M.,~Kruszewski matched with Michał Kruszewski -> M.,~Kruszewski
# looking a match for: oleksandr kshyvanskyi
# O.,~Kshyvanskyi matched with Oleksandr Kshyvanskyi -> O.,~Kshyvanskyi
# looking a match for: bogumil kubiak
# B.,~Kubiak matched with Bogumił Kubiak -> B.,~Kubiak
# looking a match for: andrej kugler
# A.,~Kugler matched with Andrej Kugler -> A.,~Kugler
# looking a match for: ajay kumar
# A.,~Kumar matched with Ajay Kumar -> A.,~Kumar
# looking a match for: ajit kumar
# A.,~Kumar matched with Ajit Kumar -> A.,~Kumar
# looking a match for: lokesh kumar
# L.,~Kumar matched with Lokesh Kumar -> L.,~Kumar
# looking a match for: volodymyr kyva
# V.,~Kyva matched with Volodymyr Kyva -> V.,~Kyva
# looking a match for: robin lakos
# R.,~Lakos matched with Robin Lakos -> R.,~Lakos
# looking a match for: rafal lalik
# R.,~Lalik matched with Rafał Lalik -> R.,~Lalik
# looking a match for: pawel lasko
# P.,~Lasko matched with Paweł Lasko -> P.,~Lasko
# looking a match for: evgeny lavrik
# E.,~Lavrik matched with Evgeny Lavrik -> E.,~Lavrik
# looking a match for: ionel lazanu
# I.,~Lazanu matched with Ionel Lazanu -> I.,~Lazanu
# looking a match for: jorg lehnert
# J.,~Lehnert matched with Jörg Lehnert -> J.,~Lehnert
# looking a match for: yue hang leung
# Y.H.,~Leung matched with Yue Hang Leung -> Y.H.,~Leung
# looking a match for: shuang li
# S.,~Li matched with Shuang Li -> S.,~Li
# looking a match for: wen li
# W.,~Li matched with Wen Li -> W.,~Li
# looking a match for: yuanjing li
# Y.,~Li matched with Yuanjing Li -> Y.,~Li
# looking a match for: volker lindenstruth
# V.,~Lindenstruth matched with Volker Lindenstruth -> V.,~Lindenstruth
# looking a match for: frederic julian linz
# F.J.,~Linz matched with Frederic Julian Linz -> F.J.,~Linz
# looking a match for: feng liu
# F.,~Liu matched with Feng Liu -> F.,~Liu
# looking a match for: sven lochner
# S.,~Löchner matched with Sven Löchner -> S.,~Löchner
# looking a match for: pierre-alain loizeau
# P.-A.,~Loizeau matched with Pierre-Alain Loizeau -> P.-A.,~Loizeau
# looking a match for: manuel lorenz
# M.,~Lorenz matched with Manuel Lorenz -> M.,~Lorenz
# looking a match for: oleksii lubynets
# O.,~Lubynets matched with Oleksii Lubynets -> O.,~Lubynets
# looking a match for: xiaofeng luo
# X.,~Luo matched with Xiaofeng Luo -> X.,~Luo
# looking a match for: anton lymanets
# A.,~Lymanets matched with Anton Lymanets -> A.,~Lymanets
# looking a match for: sanjay mahajan
# S.,~Mahajan matched with Sanjay Mahajan -> S.,~Mahajan
# looking a match for: zbigniew majka
# Z.,~Majka matched with Zbigniew Majka -> Z.,~Majka
# looking a match for: biswajit mallick
# B.,~Mallick matched with Biswajit Mallick -> B.,~Mallick
# looking a match for: subir mandal
# S.,~Mandal matched with Subir Mandal -> S.,~Mandal
# looking a match for: yaxian mao
# Y.,~Mao matched with Yaxian Mao -> Y.,~Mao
# looking a match for: osnan maragoto rodriguez
# O.,~Maragoto~Rodríguez matched with Osnan Maragoto Rodríguez -> O.,~Maragoto~Rodríguez
# looking a match for: ana maria marin garcia
# A.M.,~Marin~Garcia matched with Ana Maria Marin Garcia -> A.M.,~Marin~Garcia
# looking a match for: jochen markert
# J.,~Markert matched with Jochen Markert -> J.,~Markert
# looking a match for: franz alexej matejcek
# F.A.,~Matejcek matched with Franz Alexej Matejcek -> F.A.,~Matejcek
# looking a match for: tomasz matulewicz
# T.,~Matulewicz matched with Tomasz Matulewicz -> T.,~Matulewicz
# looking a match for: johan messchendorp
# J.,~Messchendorp matched with Johan Messchendorp -> J.,~Messchendorp
# looking a match for: shaifali mehta
# S.,~Mehta matched with Shaifali Mehta -> S.,~Mehta
# looking a match for: adrian meyer-ahrens
# A.,~Meyer-Ahrens matched with Adrian Meyer-Ahrens -> A.,~Meyer-Ahrens
# looking a match for: jan michel
# J.,~Michel matched with Jan Michel -> J.,~Michel
# looking a match for: m. farooq mir
# M.F.,~Mir matched with M. Farooq Mir -> M.F.,~Mir
# looking a match for: dariusz miskowiec
# D.,~Miskowiec matched with Dariusz Miskowiec -> D.,~Miskowiec
# looking a match for: akhil mithran
# A.,~Mithran matched with Akhil Mithran -> A.,~Mithran
# looking a match for: bedangadas mohanty
# B.,~Mohanty matched with Bedangadas Mohanty -> B.,~Mohanty
# looking a match for: ievgeniia momot
# I.,~Momot matched with Ievgeniia Momot -> I.,~Momot
# looking a match for: denise moreira de godoy willems
# D.,~Moreira~de~Godoy~Willems matched with Denise Moreira de Godoy Willems -> D.,~Moreira~de~Godoy~Willems
# looking a match for: walter f.j. muller
# W.F.J.,~Müller matched with Walter F.J. Müller -> W.F.J.,~Müller
# looking a match for: christian muntz
# C.,~Müntz matched with Christian Müntz -> C.,~Müntz
# looking a match for: philipp munkes
# P.,~Munkes matched with Philipp Munkes -> P.,~Munkes
# looking a match for: marvin nabroth
# M.,~Nabroth matched with Marvin Nabroth -> M.,~Nabroth
# looking a match for: ekata nandy
# E.,~Nandy matched with Ekata Nandy -> E.,~Nandy
# looking a match for: satya ranjan nayak
# S.R.,~Nayak matched with Satya Ranjan Nayak -> S.R.,~Nayak
# looking a match for: frank nerling
# F.,~Nerling matched with Frank Nerling -> F.,~Nerling
# looking a match for: simon neuhaus
# S.,~Neuhaus matched with Simon Neuhaus -> S.,~Neuhaus
# looking a match for: frederike nickels
# F.,~Nickels matched with Frederike Nickels -> F.,~Nickels
# looking a match for: dachi okropiridze
# D.,~Okropiridze matched with Dachi Okropiridze -> D.,~Okropiridze
# looking a match for: antonin opichal
# A.,~Opíchal matched with Antonín Opíchal -> A.,~Opíchal
# looking a match for: piotr otfinowski
# P.,~Otfinowski matched with Piotr Otfinowski -> P.,~Otfinowski
# looking a match for: liang-ming pan
# L.,~Pan matched with Liang-ming Pan -> L.,~Pan
# looking a match for: iaroslav panasenko
# I.,~Panasenko matched with Iaroslav Panasenko -> I.,~Panasenko
# looking a match for: christian pauly
# C.,~Pauly matched with Christian Pauly -> C.,~Pauly
# looking a match for: jesus pena rodriguez
# J.,~Peña~Rodríguez matched with Jesús Peña Rodríguez -> J.,~Peña~Rodríguez
# looking a match for: omer penek
# Ö.,~Penek matched with Ömer Penek -> Ö.,~Penek
# looking a match for: sven peter
# S.,~Peter matched with Sven Peter -> S.,~Peter
# looking a match for: vojtvech petravcek
# V.,~Petráček matched with Vojtěch Petráček -> V.,~Petráček
# looking a match for: mariana petrics
# M.,~Petriş matched with Mariana Petriş -> M.,~Petriş
# looking a match for: mihai petrovici
# M.,~Petrovici matched with Mihai Petrovici -> M.,~Petrovici
# looking a match for: dennis pfeifer
# D.,~Pfeifer matched with Dennis Pfeifer -> D.,~Pfeifer
# looking a match for: krzysztof piasecki
# K.,~Piasecki matched with Krzysztof Piasecki -> K.,~Piasecki
# looking a match for: jerzy pietraszko
# J.,~Pietraszko matched with Jerzy Pietraszko -> J.,~Pietraszko
# looking a match for: roman planeta
# R.,~Płaneta matched with Roman Płaneta -> R.,~Płaneta
# looking a match for: vladimir plujko
# V.,~Plujko matched with Vladimir Plujko -> V.,~Plujko
# looking a match for: jan pluta
# J.,~Pluta matched with Jan Pluta -> J.,~Pluta
# looking a match for: nikolai podgornov
# N.,~Podgornov matched with Nikolai Podgornov -> N.,~Podgornov
# looking a match for: tetiana povar
# T.,~Povar matched with Tetiana Povar -> T.,~Povar
# looking a match for: krzysztof pozniak
# K.,~Poźniak matched with Krzysztof Poźniak -> K.,~Poźniak
# looking a match for: sidharth kumar prasad
# S.K.,~Prasad matched with Sidharth Kumar Prasad -> S.K.,~Prasad
# looking a match for: mykhailo pugach
# M.,~Pugach matched with Mykhailo Pugach -> M.,~Pugach
# looking a match for: valery pugatch
# V.,~Pugatch matched with Valery Pugatch -> V.,~Pugatch
# looking a match for: axel puntke
# A.,~Puntke matched with Axel Puntke -> A.,~Puntke
# looking a match for: laura radulescu
# L.,~Radulescu matched with Laura Radulescu -> L.,~Radulescu
# looking a match for: sibaji raha
# S.,~Raha matched with Sibaji Raha -> S.,~Raha
# looking a match for: dario alberto ramirez zaldivar
# D.A.,~Ramírez~Zaldivar matched with Dario Alberto Ramírez Zaldivar -> D.A.,~Ramírez~Zaldivar
# looking a match for: rajarshi ray
# R.,~Ray matched with Rajarshi Ray -> R.,~Ray
# looking a match for: andreas redelbach
# A.,~Redelbach matched with Andreas Redelbach -> A.,~Redelbach
# looking a match for: alexander reinefeld
# A.,~Reinefeld matched with Alexander Reinefeld -> A.,~Reinefeld
# looking a match for: simon patrik reiter
# S.P.,~Reiter matched with Simon Patrik Reiter -> S.P.,~Reiter
# looking a match for: oana ristea
# O.,~Ristea matched with Oana Ristea -> O.,~Ristea
# looking a match for: james ritman
# J.,~Ritman matched with James Ritman -> J.,~Ritman
# looking a match for: dairon rodriguez garces
# D.,~Rodríguez~Garces matched with Dairon Rodríguez Garces -> D.,~Rodríguez~Garces
# looking a match for: adrian rodriguez rodriguez
# A.,~Rodríguez~Rodríguez matched with Adrian Rodríguez Rodríguez -> A.,~Rodríguez~Rodríguez
# looking a match for: florian roether
# F.,~Roether matched with Florian Roether -> F.,~Roether
# looking a match for: ryszard romaniuk
# R.,~Romaniuk matched with Ryszard Romaniuk -> R.,~Romaniuk
# looking a match for: adrian rost
# A.,~Rost matched with Adrian Rost -> A.,~Rost
# looking a match for: ankhi roy
# A.,~Roy matched with Ankhi Roy -> A.,~Roy
# looking a match for: shreya roy
# S.,~Roy matched with Shreya Roy -> S.,~Roy
# looking a match for: esteban rubio
# E.,~Rubio matched with Esteban Rubio -> E.,~Rubio
# looking a match for: anar rustamov
# A.,~Rustamov matched with Anar Rustamov -> A.,~Rustamov
# looking a match for: raghunath sahoo
# R.,~Sahoo matched with Raghunath Sahoo -> R.,~Sahoo
# looking a match for: pradip kumar sahu
# P.K.,~Sahu matched with Pradip Kumar Sahu -> P.K.,~Sahu
# looking a match for: sanjib kumar sahu
# S.K.,~Sahu matched with Sanjib Kumar Sahu -> S.K.,~Sahu
# looking a match for: jogender saini
# J.,~Saini matched with Jogender Saini -> J.,~Saini
# looking a match for: piotr salabura
# P.,~Salabura matched with Piotr Salabura -> P.,~Salabura
# looking a match for: sumanta samal
# S.,~Samal matched with Sumanta Samal -> S.,~Samal
# looking a match for: sanjeev singh sambyal
# S.S.,~Sambyal matched with Sanjeev Singh Sambyal -> S.S.,~Sambyal
# looking a match for: katia santos marrero
# K.,~Santos~Marrero matched with Katia Santos Marrero -> K.,~Santos~Marrero
# looking a match for: karina scharmann
# K.,~Scharmann matched with Karina Scharmann -> K.,~Scharmann
# looking a match for: claudiu schiaua
# C.,~Schiaua matched with Claudiu Schiaua -> C.,~Schiaua
# looking a match for: florian schintke
# F.,~Schintke matched with Florian Schintke -> F.,~Schintke
# looking a match for: david schledt
# D.,~Schledt matched with David Schledt -> D.,~Schledt
# looking a match for: christian joachim schmidt
# C.J.,~Schmidt matched with Christian Joachim Schmidt -> C.J.,~Schmidt
# looking a match for: hans rudolf schmidt
# H.R.,~Schmidt matched with Hans Rudolf Schmidt -> H.R.,~Schmidt
# looking a match for: kerstin schunemann
# K.,~Schünemann matched with Kerstin Schünemann -> K.,~Schünemann
# looking a match for: florian-johannes seck
# F.-J.,~Seck matched with Florian-Johannes Seck -> F.-J.,~Seck
# looking a match for: thomas sefzick
# T.,~Sefzick matched with Thomas Sefzick -> T.,~Sefzick
# looking a match for: ilya selyuzhenkov
# I.,~Selyuzhenkov matched with Ilya Selyuzhenkov -> I.,~Selyuzhenkov
# looking a match for: patryk semeniuk
# P.,~Semeniuk matched with Patryk Semeniuk -> P.,~Semeniuk
# looking a match for: arindam sen
# A.,~Sen matched with Arindam Sen -> A.,~Sen
# looking a match for: anna senger
# A.,~Senger matched with Anna Senger -> A.,~Senger
# looking a match for: peter senger
# P.,~Senger matched with Peter Senger -> P.,~Senger
# looking a match for: abhishek kumar sharma
# A.K.,~Sharma matched with Abhishek Kumar Sharma -> A.K.,~Sharma
# looking a match for: anjali sharma
# A.,~Sharma matched with Anjali Sharma -> A.,~Sharma
# looking a match for: anju sharma
# A.,~Sharma matched with Anju Sharma -> A.,~Sharma
# looking a match for: pawan kumar sharma
# P.K.,~Sharma matched with Pawan Kumar Sharma -> P.K.,~Sharma
# looking a match for: shusu shi
# S.,~Shi matched with Shusu Shi -> S.,~Shi
# looking a match for: mehulkumar shiroya
# M.,~Shiroya matched with Mehulkumar Shiroya -> M.,~Shiroya
# looking a match for: vladimir sidorenko
# V.,~Sidorenko matched with Vladimir Sidorenko -> V.,~Sidorenko
# looking a match for: frank simon
# F.,~Simon matched with Frank Simon -> F.,~Simon
# looking a match for: carmen simons
# C.,~Simons matched with Carmen Simons -> C.,~Simons
# looking a match for: ajay kumar singh
# A.K.,~Singh matched with Ajay Kumar Singh -> A.K.,~Singh
# looking a match for: bhartendu kumar singh
# B.K.,~Singh matched with Bhartendu Kumar Singh -> B.K.,~Singh
# looking a match for: omveer singh
# O.,~Singh matched with Omveer Singh -> O.,~Singh
# looking a match for: ranbir singh
# R.,~Singh matched with Ranbir Singh -> R.,~Singh
# looking a match for: vikas singhal
# V.,~Singhal matched with Vikas Singhal -> V.,~Singhal
# looking a match for: dominik smith
# D.,~Smith matched with Dominik Smith -> D.,~Smith
# looking a match for: bartosz sobol
# B.,~Soból matched with Bartosz Soból -> B.,~Soból
# looking a match for: yannick sohngen
# Y.,~Söhngen matched with Yannick Söhngen -> Y.,~Söhngen
# looking a match for: dennis spicker
# D.,~Spicker matched with Dennis Spicker -> D.,~Spicker
# looking a match for: pawel staszel
# P.,~Staszel matched with Paweł Staszel -> P.,~Staszel
# looking a match for: tobias stockmanns
# T.,~Stockmanns matched with Tobias Stockmanns -> T.,~Stockmanns
# looking a match for: joachim stroth
# J.,~Stroth matched with Joachim Stroth -> J.,~Stroth
# looking a match for: christian sturm
# C.,~Sturm matched with Christian Sturm -> C.,~Sturm
# looking a match for: pavish subramani
# P.,~Subramani matched with Pavish Subramani -> P.,~Subramani
# looking a match for: gnana sindhu subramanya
# G.S.,~Subramanya matched with Gnana Sindhu Subramanya -> G.S.,~Subramanya
# looking a match for: oleksandre suddia
# O.,~Suddia matched with Oleksandre Suddia -> O.,~Suddia
# looking a match for: kai sun
# K.,~Sun matched with Kai Sun -> K.,~Sun
# looking a match for: yongjie sun
# Y.,~Sun matched with Yongjie Sun -> Y.,~Sun
# looking a match for: zhengyang sun
# Z.,~Sun matched with Zhengyang Sun -> Z.,~Sun
# looking a match for: robert szczygiel
# R.,~Szczygieł matched with Robert Szczygieł -> R.,~Szczygieł
# looking a match for: eva-dhidho taka
# E.D.,~Taka matched with Eva-dhidho Taka -> E.D.,~Taka
# looking a match for: jenny taylor
# J.,~Taylor matched with Jenny Taylor -> J.,~Taylor
# looking a match for: maksym teklishyn
# M.,~Teklishyn matched with Maksym Teklishyn -> M.,~Teklishyn
# looking a match for: savina noelle thau
# S.N.,~Thau matched with Savina Noelle Thau -> S.N.,~Thau
# looking a match for: jens thaufelder
# J.,~Thaufelder matched with Jens Thaufelder -> J.,~Thaufelder
# looking a match for: alberica toia
# A.,~Toia matched with Alberica Toia -> A.,~Toia
# looking a match for: michael traxler
# M.,~Traxler matched with Michael Traxler -> M.,~Traxler
# looking a match for: lechoslaw trkebacz
# L.,~Trębacz matched with Lechosław Trębacz -> L.,~Trębacz
# looking a match for: ekaterina trifonova
# E.,~Trifonova matched with Ekaterina Trifonova -> E.,~Trifonova
# looking a match for: anna twarowska
# A.,~Twarowska matched with Anna Twarowska -> A.,~Twarowska
# looking a match for: oddharak tyagi
# O.,~Tyagi matched with Oddharak Tyagi -> O.,~Tyagi
# looking a match for: florian uhlig
# F.,~Uhlig matched with Florian Uhlig -> F.,~Uhlig
# looking a match for: kai lukas unger
# K.L.,~Unger matched with Kai Lukas Unger -> K.L.,~Unger
# looking a match for: iouri vassiliev
# I.,~Vassiliev matched with Iouri Vassiliev -> I.,~Vassiliev
# looking a match for: oleg vasylyev
# O.,~Vasylyev matched with Oleg Vasylyev -> O.,~Vasylyev
# looking a match for: robert visinka
# R.,~Visinka matched with Robert Visinka -> R.,~Visinka
# looking a match for: elena volkova
# E.,~Volkova matched with Elena Volkova -> E.,~Volkova
# looking a match for: lukas wahmes
# L.,~Wahmes matched with Lukas Wahmes -> L.,~Wahmes
# looking a match for: kaiyang wang
# K.,~Wang matched with Kaiyang Wang -> K.,~Wang
# looking a match for: yi wang
# Y.,~Wang matched with Yi Wang -> Y.,~Wang
# looking a match for: philipp weidenkaff
# P.,~Weidenkaff matched with Philipp Weidenkaff -> P.,~Weidenkaff
# looking a match for: felix weiglhofer
# F.,~Weiglhofer matched with Felix Weiglhofer -> F.,~Weiglhofer
# looking a match for: johannes p. wessels
# J.P.,~Wessels matched with Johannes P. Wessels -> J.P.,~Wessels
# looking a match for: daniel wielanek
# D.,~Wielanek matched with Daniel Wielanek -> D.,~Wielanek
# looking a match for: andrzej wieloch
# A.,~Wieloch matched with Andrzej Wieloch -> A.,~Wieloch
# looking a match for: andrea wilms
# A.,~Wilms matched with Andrea Wilms -> A.,~Wilms
# looking a match for: peter wintz
# P.,~Wintz matched with Peter Wintz -> P.,~Wintz
# looking a match for: marcin wojtkowski
# M.,~Wojtkowski matched with Marcin Wojtkowski -> M.,~Wojtkowski
# looking a match for: gyorgy wolf
# Gy.,~Wolf matched with György Wolf -> Gy.,~Wolf
# looking a match for: ke-jun wu
# K.,~Wu matched with Ke-Jun Wu -> K.,~Wu
# looking a match for: qiqi wu
# Q.,~Wu matched with Qiqi Wu -> Q.,~Wu
# looking a match for: aleksander wy.zykowski
# A.,~Wyżykowski matched with Aleksander Wyżykowski -> A.,~Wyżykowski
# looking a match for: huagen xu
# H.,~Xu matched with Huagen Xu -> H.,~Xu
# looking a match for: junfeng yang
# J.,~Yang matched with Junfeng Yang -> J.,~Yang
# looking a match for: ruijia yang
# R.,~Yang matched with Ruijia Yang -> R.,~Yang
# looking a match for: ming yao
# M.,~Yao matched with Ming Yao -> M.,~Yao
# looking a match for: zhongbao yin
# Z.,~Yin matched with Zhongbao Yin -> Z.,~Yin
# looking a match for: in-kwon yoo
# I.,~Yoo matched with In-Kwon Yoo -> I.,~Yoo
# looking a match for: wojciech zabolotny
# W.,~Zabołotny matched with Wojciech Zabołotny -> W.,~Zabołotny
# looking a match for: hanna paulina zbroszczyk
# H.P.,~Zbroszczyk matched with Hanna Paulina Zbroszczyk -> H.P.,~Zbroszczyk
# looking a match for: xiaoming zhang
# X.,~Zhang matched with Xiaoming Zhang -> X.,~Zhang
# looking a match for: xin zhang
# X.,~Zhang matched with Xin Zhang -> X.,~Zhang
# looking a match for: sergei zharko
# S.,~Zharko matched with Sergei Zharko -> S.,~Zharko
# looking a match for: sheng zheng
# S.,~Zheng matched with Sheng Zheng -> S.,~Zheng
# looking a match for: daicui zhou
# D.,~Zhou matched with Daicui Zhou -> D.,~Zhou
# looking a match for: wenxiong zhou
# W.,~Zhou matched with Wenxiong Zhou -> W.,~Zhou
# looking a match for: yingjie zhou
# Y.,~Zhou matched with Yingjie Zhou -> Y.,~Zhou
# looking a match for: xianglei zhu
# X.,~Zhu matched with Xianglei Zhu -> X.,~Zhu
# looking a match for: gianna zischka
# G.,~Zischka matched with Gianna Zischka -> G.,~Zischka
# looking a match for: weronika zubrzycka
# W.,~Zubrzycka matched with Weronika Zubrzycka -> W.,~Zubrzycka
# looking a match for: peter zumbruch
# P.,~Zumbruch matched with Peter Zumbruch -> P.,~Zumbruch
# 343 343
# []
